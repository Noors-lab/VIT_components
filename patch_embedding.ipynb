# %% [markdown]
# <a href="https://colab.research.google.com/github/Noors-lab/VIT_components/blob/main/patch_embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # the libraries

# %%
import torch
import torch.nn as nn

# %% [markdown]
# patch_embedding

# %%
class patchembedding(nn.Module):
  def __init__(self,img_size=32,patch_size=4,in_channels=3,embed_dim=128):
    super().__init__()
    self.proj=nn.Conv2d(
        in_channels=in_channels,
        stride=patch_size,
        kernel_size=patch_size,
        out_channels=embed_dim

    )

  def forward(self,x):
    x = self.proj(x)
    x = x.flatten(2)
    x = x.transpose(1,2)
    return x

# %% [markdown]
# testing

# %%
X = torch.randn(2, 3, 32, 32)
patch_embed = patchembedding(X)
tokens = patch_embed(X)
print(tokens.shape)
# Out:
# torch.Size([2, 64, 128])
